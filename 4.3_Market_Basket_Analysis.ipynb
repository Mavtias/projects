# %% [markdown]
# # Reglas de asociación y market-basket analysis

# %% [markdown]
# Las reglas de asociación permiten encontrar patrones comunes en grandes conjuntos de datos.
#
# En este caso para identificar los productos que se compra de forma conjunta en una tienda.

# %% [markdown]
# Proceso:

# %% [markdown]
# Instalamos la libreria MLxtend con "pip install mlxtend" y importamos en nuestro notebook para trabajar con los algoritmos de Apriori y Reglas de Asociacion junto con Pandas

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %% [markdown]
# Importamos nuestra base de datos

# %%
df = pd.read_csv("factura_final_mediana.csv")
df.head(30)
# Out:
#     Codigo                                      Producto  Unidades  Precio  \
# 0     1119                                 Fruta al peso     1.110    1.05
# 1     1035                             Cerveza 33cl SKOL     6.000    3.00
# 2     1031              Cerveza sin 0,0 33cl SAN MIGUEL      1.000    0.70
# 3     1060                              Agua 1,5L BEZOYA     1.000    0.70
# 4      421              Tomate frito 265gr brick ORLANDO     1.000    0.50
# 5     1067                         Cerveza 1l SAN MIGUEL     1.000    1.50
# 6     1078                                  Chuches 0.05    20.000    1.00
# 7     1072                   Agua garrafa 5l FONT NATURA     2.000    1.80
# 8     1119                                 Fruta al peso     0.245    0.47
# 9     1066                            Agua 1,5L LANJARON     1.000    0.70
# 10     903   Cafe helado para beber  vaso 230ml LANDESSA     1.000    1.30
# 11     904     Cafe helado para beber vaso 250ml  KALISE     1.000    1.30
# 12     904     Cafe helado para beber vaso 250ml  KALISE     1.000    1.30
# 13    1116                            Kinder bueno white     1.000    1.00
# 14     950  Queso tierno bajo en sal 80gr GARCIA BAQUERO     1.000    1.00
# 15     950  Queso tierno bajo en sal 80gr GARCIA BAQUERO     1.000    1.00
# 16    1072                   Agua garrafa 5l FONT NATURA     1.000    0.90
# 17    1072                   Agua garrafa 5l FONT NATURA     1.000    0.90
# 18    1028                          Aquarius limon 1,5L      1.000    2.00
# 19    1028                          Aquarius limon 1,5L      1.000    2.00
# 20    1116                            Kinder bueno white     1.000    1.00
# 21    1062                            Agua 1,5L FONTAREL     1.000    0.70
# 22     927                        Bacalao palito ALBACOR     1.000    1.99
# 23     927                        Bacalao palito ALBACOR     1.000    1.99
# 24    1062                            Agua 1,5L FONTAREL     1.000    0.70
# 25    1062                            Agua 1,5L FONTAREL     1.000    0.70
# 26    1119                                 Fruta al peso     0.240    0.94
# 27    1119                                 Fruta al peso     0.640    1.22
# 28    1119                                 Fruta al peso     0.230    0.38
# 29    1119                                 Fruta al peso     0.410    0.64
#
#     Num_Factura  Precio_Unit  Total   Coste  Seccion           Fecha_Hora  \
# 0             1         0.95   1.05  0.7600      7.0  2015-08-16 22:43:00
# 1             2         0.50   3.00  0.2800     10.0  2015-08-16 22:59:00
# 2             3         0.70   1.90  0.3990     10.0  2015-08-20 22:39:00
# 3             3         0.70   1.90  0.3570     10.0  2015-08-20 22:39:00
# 4             3         0.50   1.90  0.3000      7.0  2015-08-20 22:39:00
# 5             4         1.50   2.50  1.0050     10.0  2015-08-20 22:56:00
# 6             4         0.05   2.50  0.0400      7.0  2015-08-20 22:56:00
# 7             5         0.90   1.80  0.5310     10.0  2015-08-21 08:48:00
# 8             6         1.90   0.47  1.5200      7.0  2015-08-21 09:20:59
# 9             7         0.70   2.00  0.3780     10.0  2015-08-21 09:38:59
# 10            7         1.30   2.00  0.7670     10.0  2015-08-21 09:38:59
# 11            8         1.30   2.80  0.7540     10.0  2015-08-21 09:42:00
# 12            8         1.30   4.90  0.7540     10.0  2015-08-21 08:53:00
# 13            8         1.00   4.90  0.6800      7.0  2015-08-21 08:53:00
# 14            8         1.00   2.80  0.7500      7.0  2015-08-21 09:42:00
# 15            8         1.00   4.90  0.7500      7.0  2015-08-21 08:53:00
# 16            8         0.90   2.80  0.5310     10.0  2015-08-21 09:42:00
# 17            8         0.90   4.90  0.5310     10.0  2015-08-21 08:53:00
# 18            8         2.00   2.80  1.4000      1.0  2015-08-21 09:42:00
# 19            8         2.00   4.90  1.4000      1.0  2015-08-21 08:53:00
# 20            8         1.00   2.80  0.6800      7.0  2015-08-21 09:42:00
# 21            9         0.70   0.70  0.1470     10.0  2015-08-21 10:07:00
# 22           10         1.99   1.99  1.6119      7.0  2015-08-21 10:12:00
# 23           10         1.99   0.70  1.6119      7.0  2015-08-21 09:24:59
# 24           10         0.70   0.70  0.1470     10.0  2015-08-21 09:24:59
# 25           10         0.70   1.99  0.1470     10.0  2015-08-21 10:12:00
# 26           11         3.90   7.19  3.1200      7.0  2015-08-21 10:20:00
# 27           11         1.90   7.19  1.5200      7.0  2015-08-21 10:20:00
# 28           11         1.65   7.19  1.3200      7.0  2015-08-21 10:20:00
# 29           11         1.55   7.19  1.2400      7.0  2015-08-21 10:20:00
#
#     Margen_Producto  %_Margen_Producto
# 0            0.1900               0.20
# 1            0.2200               0.44
# 2            0.3010               0.43
# 3            0.3430               0.49
# 4            0.2000               0.40
# 5            0.4950               0.33
# 6            0.0100               0.20
# 7            0.3690               0.41
# 8            0.3800               0.20
# 9            0.3220               0.46
# 10           0.5330               0.41
# 11           0.5460               0.42
# 12           0.5460               0.42
# 13           0.3200               0.32
# 14           0.2500               0.25
# 15           0.2500               0.25
# 16           0.3690               0.41
# 17           0.3690               0.41
# 18           0.6000               0.30
# 19           0.6000               0.30
# 20           0.3200               0.32
# 21           0.5530               0.79
# 22           0.3781               0.19
# 23           0.3781               0.19
# 24           0.5530               0.79
# 25           0.5530               0.79
# 26           0.7800               0.20
# 27           0.3800               0.20
# 28           0.3300               0.20
# 29           0.3100               0.20

# %% [markdown]
# Para hacer el modelos,hay que eliminar los espacios que continene en las descripciones contienen espacios que ha de ser eliminados.

# %%
df['Producto'] = df['Producto'].str.strip()

# %% [markdown]
# Creamos una variable "basket" con una query que esta filtrada previamente por las bebidas, con el Numero de factura y productos por sus unidades. Cada una de las filas representa una factura y cada una de las columnas un producto, e indica el numero resultante indica el total de unidades de cada producto vendido en cada factura.

# %%
basket = (df.query("Seccion==88").groupby(['Num_Factura', 'Producto'])['Unidades'].sum().unstack().reset_index().fillna(0).set_index('Num_Factura'))

# %%
basket
# Out:
# Producto     AGUA 8L MIJAS  AGUA ERMITICA 1.5L  AGUA SOLAN DE CABRAS 1.5L  \
# Num_Factura
# 2                      0.0                 0.0                        0.0
# 3                      0.0                 0.0                        0.0
# 4                      0.0                 0.0                        0.0
# 5                      0.0                 0.0                        0.0
# 7                      0.0                 0.0                        0.0
# ...                    ...                 ...                        ...
# 467102                 0.0                 0.0                        0.0
# 467104                 0.0                 0.0                        0.0
# 467106                 0.0                 0.0                        0.0
# 467107                 0.0                 0.0                        0.0
# 467110                 0.0                 0.0                        0.0
#
# Producto     AGUA0.5LEL CAÑAR  AMSTEL RADLER  Agua 0.5L fuente primavera  \
# Num_Factura
# 2                         0.0            0.0                         0.0
# 3                         0.0            0.0                         0.0
# 4                         0.0            0.0                         0.0
# 5                         0.0            0.0                         0.0
# 7                         0.0            0.0                         0.0
# ...                       ...            ...                         ...
# 467102                    0.0            0.0                         0.0
# 467104                    0.0            0.0                         0.0
# 467106                    0.0            0.0                         0.0
# 467107                    0.0            0.0                         0.0
# 467110                    0.0            0.0                         0.0
#
# Producto     Agua 1,5L BEZOYA  Agua 1,5L FONT VELLA  Agua 1,5L FONTAREL  \
# Num_Factura
# 2                         0.0                   0.0                 0.0
# 3                         1.0                   0.0                 0.0
# 4                         0.0                   0.0                 0.0
# 5                         0.0                   0.0                 0.0
# 7                         0.0                   0.0                 0.0
# ...                       ...                   ...                 ...
# 467102                    0.0                   0.0                 0.0
# 467104                    0.0                   0.0                 0.0
# 467106                    0.0                   0.0                 0.0
# 467107                    0.0                   0.0                 0.0
# 467110                    0.0                   0.0                 0.0
#
# Producto     Agua 1,5L LANJARON  ...  \
# Num_Factura                      ...
# 2                           0.0  ...
# 3                           0.0  ...
# 4                           0.0  ...
# 5                           0.0  ...
# 7                           1.0  ...
# ...                         ...  ...
# 467102                      0.0  ...
# 467104                      0.0  ...
# 467106                      0.0  ...
# 467107                      0.0  ...
# 467110                      0.0  ...
#
# Producto     tinto de verano la casera Limón Sin Alcohol  \
# Num_Factura
# 2                                                    0.0
# 3                                                    0.0
# 4                                                    0.0
# 5                                                    0.0
# 7                                                    0.0
# ...                                                  ...
# 467102                                               0.0
# 467104                                               0.0
# 467106                                               0.0
# 467107                                               0.0
# 467110                                               0.0
#
# Producto     tinto verano sin alcohol LA CASERA  tonica 1L zero  \
# Num_Factura
# 2                                           0.0             0.0
# 3                                           0.0             0.0
# 4                                           0.0             0.0
# 5                                           0.0             0.0
# 7                                           0.0             0.0
# ...                                         ...             ...
# 467102                                      0.0             0.0
# 467104                                      0.0             0.0
# 467106                                      0.0             0.0
# 467107                                      0.0             0.0
# 467110                                      0.0             0.0
#
# Producto     trina naranja  zumo de melocoton juver  \
# Num_Factura
# 2                      0.0                      0.0
# 3                      0.0                      0.0
# 4                      0.0                      0.0
# 5                      0.0                      0.0
# 7                      0.0                      0.0
# ...                    ...                      ...
# 467102                 0.0                      0.0
# 467104                 0.0                      0.0
# 467106                 0.0                      0.0
# 467107                 0.0                      0.0
# 467110                 0.0                      0.0
#
# Producto     zumo de naranja de la verja  zumo juver sin azucar piña 1l  \
# Num_Factura
# 2                                    0.0                            0.0
# 3                                    0.0                            0.0
# 4                                    0.0                            0.0
# 5                                    0.0                            0.0
# 7                                    0.0                            0.0
# ...                                  ...                            ...
# 467102                               0.0                            0.0
# 467104                               0.0                            0.0
# 467106                               0.0                            0.0
# 467107                               0.0                            0.0
# 467110                               0.0                            0.0
#
# Producto     zumo manzana eliges 1l  zumo melocoton  zumo naranja DON SIMON
# Num_Factura
# 2                               0.0             0.0                     0.0
# 3                               0.0             0.0                     0.0
# 4                               0.0             0.0                     0.0
# 5                               0.0             0.0                     0.0
# 7                               0.0             0.0                     0.0
# ...                             ...             ...                     ...
# 467102                          0.0             0.0                     0.0
# 467104                          0.0             0.0                     0.0
# 467106                          0.0             0.0                     0.0
# 467107                          0.0             0.0                     0.0
# 467110                          0.0             0.0                     0.0
#
# [192421 rows x 329 columns]

# %% [markdown]
# Se define una funcion que da valores 0 si el valor es igual a 0, o 1 en caso contrario y se aplica a la variable basket previamente creada

# %%
def encode_units(x):
    if x == 0:
        return 0
    if x > 0:
        return 1

# %%
basket_sets = basket.applymap(encode_units)

# %%
basket_sets
# Out:
# Producto     AGUA 8L MIJAS  AGUA ERMITICA 1.5L  AGUA SOLAN DE CABRAS 1.5L  \
# Num_Factura
# 2                        0                   0                          0
# 3                        0                   0                          0
# 4                        0                   0                          0
# 5                        0                   0                          0
# 7                        0                   0                          0
# ...                    ...                 ...                        ...
# 467102                   0                   0                          0
# 467104                   0                   0                          0
# 467106                   0                   0                          0
# 467107                   0                   0                          0
# 467110                   0                   0                          0
#
# Producto     AGUA0.5LEL CAÑAR  AMSTEL RADLER  Agua 0.5L fuente primavera  \
# Num_Factura
# 2                           0              0                           0
# 3                           0              0                           0
# 4                           0              0                           0
# 5                           0              0                           0
# 7                           0              0                           0
# ...                       ...            ...                         ...
# 467102                      0              0                           0
# 467104                      0              0                           0
# 467106                      0              0                           0
# 467107                      0              0                           0
# 467110                      0              0                           0
#
# Producto     Agua 1,5L BEZOYA  Agua 1,5L FONT VELLA  Agua 1,5L FONTAREL  \
# Num_Factura
# 2                           0                     0                   0
# 3                           1                     0                   0
# 4                           0                     0                   0
# 5                           0                     0                   0
# 7                           0                     0                   0
# ...                       ...                   ...                 ...
# 467102                      0                     0                   0
# 467104                      0                     0                   0
# 467106                      0                     0                   0
# 467107                      0                     0                   0
# 467110                      0                     0                   0
#
# Producto     Agua 1,5L LANJARON  ...  \
# Num_Factura                      ...
# 2                             0  ...
# 3                             0  ...
# 4                             0  ...
# 5                             0  ...
# 7                             1  ...
# ...                         ...  ...
# 467102                        0  ...
# 467104                        0  ...
# 467106                        0  ...
# 467107                        0  ...
# 467110                        0  ...
#
# Producto     tinto de verano la casera Limón Sin Alcohol  \
# Num_Factura
# 2                                                      0
# 3                                                      0
# 4                                                      0
# 5                                                      0
# 7                                                      0
# ...                                                  ...
# 467102                                                 0
# 467104                                                 0
# 467106                                                 0
# 467107                                                 0
# 467110                                                 0
#
# Producto     tinto verano sin alcohol LA CASERA  tonica 1L zero  \
# Num_Factura
# 2                                             0               0
# 3                                             0               0
# 4                                             0               0
# 5                                             0               0
# 7                                             0               0
# ...                                         ...             ...
# 467102                                        0               0
# 467104                                        0               0
# 467106                                        0               0
# 467107                                        0               0
# 467110                                        0               0
#
# Producto     trina naranja  zumo de melocoton juver  \
# Num_Factura
# 2                        0                        0
# 3                        0                        0
# 4                        0                        0
# 5                        0                        0
# 7                        0                        0
# ...                    ...                      ...
# 467102                   0                        0
# 467104                   0                        0
# 467106                   0                        0
# 467107                   0                        0
# 467110                   0                        0
#
# Producto     zumo de naranja de la verja  zumo juver sin azucar piña 1l  \
# Num_Factura
# 2                                      0                              0
# 3                                      0                              0
# 4                                      0                              0
# 5                                      0                              0
# 7                                      0                              0
# ...                                  ...                            ...
# 467102                                 0                              0
# 467104                                 0                              0
# 467106                                 0                              0
# 467107                                 0                              0
# 467110                                 0                              0
#
# Producto     zumo manzana eliges 1l  zumo melocoton  zumo naranja DON SIMON
# Num_Factura
# 2                                 0               0                       0
# 3                                 0               0                       0
# 4                                 0               0                       0
# 5                                 0               0                       0
# 7                                 0               0                       0
# ...                             ...             ...                     ...
# 467102                            0               0                       0
# 467104                            0               0                       0
# 467106                            0               0                       0
# 467107                            0               0                       0
# 467110                            0               0                       0
#
# [192421 rows x 329 columns]

# %% [markdown]
# La función "apriori" es una función de asociación de ítems que se utiliza para encontrar conjuntos de ítems que ocurren con cierta frecuencia en un conjunto de datos.
#
# El "min_support" es un valor numérico que especifica el umbral mínimo de soporte que deben tener los conjuntos de ítems para ser considerados frecuentes.
#
# Da lugar a un dataframe con los articulos que se repiten con ese min_support aplicado.

# %%
frequent_itemsets = apriori(basket_sets, min_support=0.001, use_colnames=True)
frequent_itemsets
# Out:
# /Users/franciscomanueljimenezpalacios/opt/anaconda3/lib/python3.9/site-packages/mlxtend/frequent_patterns/fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#       support                                   itemsets
# 0    0.009323                       (AGUA ERMITICA 1.5L)
# 1    0.001512                (AGUA SOLAN DE CABRAS 1.5L)
# 2    0.024545                         (Agua 1,5L BEZOYA)
# 3    0.003477                     (Agua 1,5L FONT VELLA)
# 4    0.003217                       (Agua 1,5L FONTAREL)
# ..        ...                                        ...
# 134  0.002339      (Coca cola 33cl, Coca cola zero 33cl)
# 135  0.001346         (Fanta limon 33cl, Coca cola 33cl)
# 136  0.002947       (Fanta naranja 33cl, Coca cola 33cl)
# 137  0.001159  (Fanta naranja 33cl, Coca cola zero 33cl)
# 138  0.001206     (Fanta naranja 33cl, Fanta limon 33cl)
#
# [139 rows x 2 columns]

# %% [markdown]
# La función de asociación de ítems que se utiliza para generar reglas de asociación a partir de conjuntos de ítems frecuentes.
# La métrica "lift", que mide la fuerza de la asociación entre dos ítems.
# "min_threshold" especifica el umbral mínimo que deben tener las reglas de asociación para ser incluidas en el resultado.

# %%
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)
rules
# Out:
#                                 antecedents  \
# 0                      (Agua 1,5L LANJARON)
# 1                          (Coca cola 33cl)
# 2            (Cerveza 33cl crital HEINEKEN)
# 3                (Agua 1,5L pack6 LANJARON)
# 4               (Alhambra Tradicional 50cl)
# 5                     (cervesa alhambra 1l)
# 6                    (Cerveza 1l CRUZCAMPO)
# 7                  (Cerveza 33cl CRUZCAMPO)
# 8                       (Cerveza 33cl SKOL)
# 9                         (Cerveza 1l SKOL)
# 10                  (Cerveza 33cl VICTORIA)
# 11                (Cerveza 33cl SAN MIGUEL)
# 12                  (Cerveza 33cl VICTORIA)
# 13                      (Cerveza 33cl SKOL)
# 14  (Coca Cola Lata 330ml Zero/sin cafeina)
# 15                      (Cerveza 33cl SKOL)
# 16                               (skol 500)
# 17                      (Cerveza 33cl SKOL)
# 18           (Cerveza 33cl crital HEINEKEN)
# 19              (Cerveza Alhambra botellin)
# 20                           (Coca cola 2L)
# 21                       (Fanta naranja 2L)
# 22                         (Coca cola 33cl)
# 23                    (Coca cola zero 33cl)
# 24                       (Fanta limon 33cl)
# 25                         (Coca cola 33cl)
# 26                     (Fanta naranja 33cl)
# 27                         (Coca cola 33cl)
# 28                     (Fanta naranja 33cl)
# 29                    (Coca cola zero 33cl)
# 30                     (Fanta naranja 33cl)
# 31                       (Fanta limon 33cl)
#
#                                 consequents  antecedent support  \
# 0                          (Coca cola 33cl)            0.016854
# 1                      (Agua 1,5L LANJARON)            0.067077
# 2                (Agua 1,5L pack6 LANJARON)            0.010389
# 3            (Cerveza 33cl crital HEINEKEN)            0.009911
# 4                     (cervesa alhambra 1l)            0.019270
# 5               (Alhambra Tradicional 50cl)            0.030911
# 6                  (Cerveza 33cl CRUZCAMPO)            0.039102
# 7                    (Cerveza 1l CRUZCAMPO)            0.047391
# 8                         (Cerveza 1l SKOL)            0.065060
# 9                       (Cerveza 33cl SKOL)            0.038146
# 10                (Cerveza 33cl SAN MIGUEL)            0.048025
# 11                  (Cerveza 33cl VICTORIA)            0.010934
# 12                      (Cerveza 33cl SKOL)            0.048025
# 13                  (Cerveza 33cl VICTORIA)            0.065060
# 14                      (Cerveza 33cl SKOL)            0.015269
# 15  (Coca Cola Lata 330ml Zero/sin cafeina)            0.065060
# 16                      (Cerveza 33cl SKOL)            0.008118
# 17                               (skol 500)            0.065060
# 18              (Cerveza Alhambra botellin)            0.010389
# 19           (Cerveza 33cl crital HEINEKEN)            0.008674
# 20                       (Fanta naranja 2L)            0.043374
# 21                           (Coca cola 2L)            0.013346
# 22                    (Coca cola zero 33cl)            0.067077
# 23                         (Coca cola 33cl)            0.031743
# 24                         (Coca cola 33cl)            0.010342
# 25                       (Fanta limon 33cl)            0.067077
# 26                         (Coca cola 33cl)            0.022492
# 27                     (Fanta naranja 33cl)            0.067077
# 28                    (Coca cola zero 33cl)            0.022492
# 29                     (Fanta naranja 33cl)            0.031743
# 30                       (Fanta limon 33cl)            0.022492
# 31                     (Fanta naranja 33cl)            0.010342
#
#     consequent support   support  confidence       lift  leverage  conviction
# 0             0.067077  0.001169    0.069380   1.034339  0.000039    1.002475
# 1             0.016854  0.001169    0.017432   1.034339  0.000039    1.000589
# 2             0.009911  0.001045    0.100550  10.145771  0.000942    1.100772
# 3             0.010389  0.001045    0.105401  10.145771  0.000942    1.106207
# 4             0.030911  0.001237    0.064186   2.076437  0.000641    1.035556
# 5             0.019270  0.001237    0.040013   2.076437  0.000641    1.021608
# 6             0.047391  0.003934    0.100611   2.123011  0.002081    1.059174
# 7             0.039102  0.003934    0.083013   2.123011  0.002081    1.047887
# 8             0.038146  0.002614    0.040179   1.053306  0.000132    1.002119
# 9             0.065060  0.002614    0.068529   1.053306  0.000132    1.003723
# 10            0.010934  0.001320    0.027486   2.513746  0.000795    1.017020
# 11            0.048025  0.001320    0.120722   2.513746  0.000795    1.082679
# 12            0.065060  0.003305    0.068824   1.057842  0.000181    1.004041
# 13            0.048025  0.003305    0.050803   1.057842  0.000181    1.002927
# 14            0.065060  0.001117    0.073179   1.124785  0.000124    1.008760
# 15            0.015269  0.001117    0.017174   1.124785  0.000124    1.001939
# 16            0.065060  0.001013    0.124840   1.918830  0.000485    1.068307
# 17            0.008118  0.001013    0.015576   1.918830  0.000485    1.007577
# 18            0.008674  0.001923    0.185093  21.339540  0.001833    1.216489
# 19            0.010389  0.001923    0.221690  21.339540  0.001833    1.271487
# 20            0.013346  0.001455    0.033549   2.513837  0.000876    1.020905
# 21            0.043374  0.001455    0.109034   2.513837  0.000876    1.073696
# 22            0.031743  0.002339    0.034865   1.098350  0.000209    1.003235
# 23            0.067077  0.002339    0.073674   1.098350  0.000209    1.007122
# 24            0.067077  0.001346    0.130151   1.940322  0.000652    1.072511
# 25            0.010342  0.001346    0.020067   1.940322  0.000652    1.009924
# 26            0.067077  0.002947    0.131007   1.953093  0.001438    1.073569
# 27            0.022492  0.002947    0.043930   1.953093  0.001438    1.022422
# 28            0.031743  0.001159    0.051525   1.623196  0.000445    1.020857
# 29            0.022492  0.001159    0.036509   1.623196  0.000445    1.014548
# 30            0.010342  0.001206    0.053604   5.183226  0.000973    1.045713
# 31            0.022492  0.001206    0.116583   5.183226  0.000973    1.106508

# %% [markdown]
# Support (Soporte) mide el porcentaje de la fuerza en la que ocurre la relacion entre el antecedente y la consecuencia.
# El Agua 1,5L LANJARON y la Coca cola 33cl aparecen juntos en los tickets en un 0.1169% de las veces.

# %% [markdown]
# La confidence (Confianza) es el porcentaje de las transacciones en las que aparece el antecedente en la que también aparece el consecuente. Lo que mide este indicador es la fiabilidad de la regla.

# %% [markdown]
# Antecedente o consecuente indica cual es el que tiene mas peso en el acompañamiento

# %% [markdown]
# La mejora de la confianza es la fracción de soporte de la regla respecto al que se observaría en caso de independía.

# %% [markdown]
# # Analisis con todos los productos

# %% [markdown]
# Eliminas el producto de Bolsas porque no es representativo en el estudio y al ser de lo mas vendido desvirtua un poco los datos

# %%
df.drop(df.query("Producto == 'Bolsa Plastico LEY'").index,axis=0,inplace=True)

# %% [markdown]
# Filtramos por el año 2021 con todos los productos

# %%
df1=df[(df['Fecha_Hora'] > '2021-01-01') & (df['Fecha_Hora'] < '2021-12-31')]

# %%
#df1['Producto'] = df1['Producto'].str.strip()
#df1.dropna(axis=0, subset=['Num_Factura'], inplace=True)
#df1['Num_Factura'] = df1['Num_Factura'].astype('str')
# Out:
# /var/folders/md/0kp4d7755rz9llrkjzrjm5000000gn/T/ipykernel_1527/1566963137.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Producto'] = df1['Producto'].str.strip()
# /var/folders/md/0kp4d7755rz9llrkjzrjm5000000gn/T/ipykernel_1527/1566963137.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.dropna(axis=0, subset=['Num_Factura'], inplace=True)
# /var/folders/md/0kp4d7755rz9llrkjzrjm5000000gn/T/ipykernel_1527/1566963137.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Num_Factura'] = df1['Num_Factura'].astype('str')

# %%
basket1 = (df1.groupby(['Num_Factura', 'Producto'])['Unidades'].sum().unstack().reset_index().fillna(0).set_index('Num_Factura'))

# %%
basket_sets1 = basket1.applymap(encode_units)
frequent_itemsets1 = apriori(basket_sets1, min_support=0.002, use_colnames=True)
# Out:
# /Users/franciscomanueljimenezpalacios/opt/anaconda3/lib/python3.9/site-packages/mlxtend/frequent_patterns/fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(

# %%
rules1 = association_rules(frequent_itemsets1, metric="lift", min_threshold=1)
rules1.head(60)
# Out:
#                             antecedents                          consequents  \
# 0                       (Fruta al peso)                         (1/2 huevos)
# 1                          (1/2 huevos)                      (Fruta al peso)
# 2                                 (Pan)                         (1/2 huevos)
# 3                          (1/2 huevos)                                (Pan)
# 4                                 (Pan)                          (12 huevos)
# 5                           (12 huevos)                                (Pan)
# 6                                 (Pan)        (Agua garrafa 8l FONT NATURA)
# 7         (Agua garrafa 8l FONT NATURA)                                (Pan)
# 8    (Blue Chameleon Bebida Energetica)                  (Cerveza 33cl SKOL)
# 9                   (Cerveza 33cl SKOL)   (Blue Chameleon Bebida Energetica)
# 10   (Blue Chameleon Bebida Energetica)                       (Chuches 0.05)
# 11                       (Chuches 0.05)   (Blue Chameleon Bebida Energetica)
# 12                 (Producto de Oferta)                  (Bocadillos oferta)
# 13                  (Bocadillos oferta)                 (Producto de Oferta)
# 14                            (Caña Qe)                 (Producto de Oferta)
# 15                 (Producto de Oferta)                            (Caña Qe)
# 16               (Cerveza 1l CRUZCAMPO)             (Cerveza 33cl CRUZCAMPO)
# 17             (Cerveza 33cl CRUZCAMPO)               (Cerveza 1l CRUZCAMPO)
# 18                                (Pan)     (Chorizo tradicion 85gr REVILLA)
# 19     (Chorizo tradicion 85gr REVILLA)                                (Pan)
# 20                       (Chuches 0.05)                 (Producto de Oferta)
# 21                 (Producto de Oferta)                       (Chuches 0.05)
# 22                (Hielo bolsa cubitos)                       (Coca cola 2L)
# 23                       (Coca cola 2L)                (Hielo bolsa cubitos)
# 24                       (Coca cola 2L)                 (Producto de Oferta)
# 25                 (Producto de Oferta)                       (Coca cola 2L)
# 26                 (Producto de Oferta)                     (Coca cola 33cl)
# 27                     (Coca cola 33cl)                 (Producto de Oferta)
# 28                 (Producto de Oferta)                (Coca cola zero 33cl)
# 29                (Coca cola zero 33cl)                 (Producto de Oferta)
# 30                  (Embutido al corte)                      (Fruta al peso)
# 31                      (Fruta al peso)                  (Embutido al corte)
# 32                                (Pan)                  (Embutido al corte)
# 33                  (Embutido al corte)                                (Pan)
# 34                  (Embutido al corte)                 (Producto de Oferta)
# 35                 (Producto de Oferta)                  (Embutido al corte)
# 36                      (Fruta al peso)         (PACK AGUA 1.5L FONT NATURA)
# 37         (PACK AGUA 1.5L FONT NATURA)                      (Fruta al peso)
# 38                                (Pan)                      (Fruta al peso)
# 39                      (Fruta al peso)                                (Pan)
# 40      (Pechuga de pavo 100gr EL POZO)                      (Fruta al peso)
# 41                      (Fruta al peso)      (Pechuga de pavo 100gr EL POZO)
# 42                      (Fruta al peso)                 (Producto de Oferta)
# 43                 (Producto de Oferta)                      (Fruta al peso)
# 44                      (Fruta al peso)                    (lechuga iceberg)
# 45                    (lechuga iceberg)                      (Fruta al peso)
# 46                                (Pan)       (Jamon Curado 8u 55gr NAVIDUL)
# 47       (Jamon Curado 8u 55gr NAVIDUL)                                (Pan)
# 48                                (Pan)         (Jamon cocido 100gr EL POZO)
# 49         (Jamon cocido 100gr EL POZO)                                (Pan)
# 50                                (Pan)                   (Pan Bimbo grande)
# 51                   (Pan Bimbo grande)                                (Pan)
# 52                                (Pan)      (Pechuga de pavo 100gr EL POZO)
# 53      (Pechuga de pavo 100gr EL POZO)                                (Pan)
# 54                                (Pan)                         (Pepsi 33cl)
# 55                         (Pepsi 33cl)                                (Pan)
# 56      (Salchichon extra 85gr REVILLA)                                (Pan)
# 57                                (Pan)      (Salchichon extra 85gr REVILLA)
# 58                                (Pan)  (queso en lonchas semi curado0.80g)
# 59  (queso en lonchas semi curado0.80g)                                (Pan)
#
#     antecedent support  consequent support   support  confidence       lift  \
# 0             0.127203            0.009624  0.003350    0.026339   2.736876
# 1             0.009624            0.127203  0.003350    0.348138   2.736876
# 2             0.276106            0.009624  0.003929    0.014231   1.478812
# 3             0.009624            0.276106  0.003929    0.408309   1.478812
# 4             0.276106            0.004991  0.002027    0.007340   1.470728
# 5             0.004991            0.276106  0.002027    0.406077   1.470728
# 6             0.276106            0.009679  0.003626    0.013133   1.356882
# 7             0.009679            0.276106  0.003626    0.374644   1.356882
# 8             0.040480            0.034896  0.003281    0.081063   2.322985
# 9             0.034896            0.040480  0.003281    0.094034   2.322985
# 10            0.040480            0.054102  0.002909    0.071866   1.328358
# 11            0.054102            0.040480  0.002909    0.053772   1.328358
# 12            0.137378            0.011292  0.002895    0.021076   1.866463
# 13            0.011292            0.137378  0.002895    0.256410   1.866463
# 14            0.012836            0.137378  0.002509    0.195489   1.423003
# 15            0.137378            0.012836  0.002509    0.018266   1.423003
# 16            0.018723            0.018310  0.003447    0.184094  10.054485
# 17            0.018310            0.018723  0.003447    0.188253  10.054485
# 18            0.276106            0.006687  0.003474    0.012584   1.881838
# 19            0.006687            0.276106  0.003474    0.519588   1.881838
# 20            0.054102            0.137378  0.009182    0.169725   1.235461
# 21            0.137378            0.054102  0.009182    0.066841   1.235461
# 22            0.023687            0.016049  0.002109    0.089057   5.549233
# 23            0.016049            0.023687  0.002109    0.131443   5.549233
# 24            0.016049            0.137378  0.002206    0.137457   1.000578
# 25            0.137378            0.016049  0.002206    0.016058   1.000578
# 26            0.137378            0.029105  0.006094    0.044360   1.524116
# 27            0.029105            0.137378  0.006094    0.209379   1.524116
# 28            0.137378            0.011885  0.002440    0.017764   1.494686
# 29            0.011885            0.137378  0.002440    0.205336   1.494686
# 30            0.034662            0.127203  0.009927    0.286396   2.251497
# 31            0.127203            0.034662  0.009927    0.078040   2.251497
# 32            0.276106            0.034662  0.018930    0.068561   1.978011
# 33            0.034662            0.276106  0.018930    0.546142   1.978011
# 34            0.034662            0.137378  0.005873    0.169451   1.233469
# 35            0.137378            0.034662  0.005873    0.042754   1.233469
# 36            0.127203            0.011444  0.002165    0.017017   1.487051
# 37            0.011444            0.127203  0.002165    0.189157   1.487051
# 38            0.276106            0.127203  0.049207    0.178218   1.401059
# 39            0.127203            0.276106  0.049207    0.386842   1.401059
# 40            0.012491            0.127203  0.002813    0.225166   1.770134
# 41            0.127203            0.012491  0.002813    0.022111   1.770134
# 42            0.127203            0.137378  0.017593    0.138305   1.006749
# 43            0.137378            0.127203  0.017593    0.128061   1.006749
# 44            0.127203            0.004550  0.002068    0.016258   3.573399
# 45            0.004550            0.127203  0.002068    0.454545   3.573399
# 46            0.276106            0.008355  0.004274    0.015480   1.852732
# 47            0.008355            0.276106  0.004274    0.511551   1.852732
# 48            0.276106            0.006521  0.003102    0.011235   1.722840
# 49            0.006521            0.276106  0.003102    0.475687   1.722840
# 50            0.276106            0.007294  0.002096    0.007590   1.040666
# 51            0.007294            0.276106  0.002096    0.287335   1.040666
# 52            0.276106            0.012491  0.006852    0.024818   1.986789
# 53            0.012491            0.276106  0.006852    0.548565   1.986789
# 54            0.276106            0.009306  0.002840    0.010287   1.105317
# 55            0.009306            0.276106  0.002840    0.305185   1.105317
# 56            0.006177            0.276106  0.003543    0.573661   2.077680
# 57            0.276106            0.006177  0.003543    0.012833   2.077680
# 58            0.276106            0.006425  0.003281    0.011885   1.849756
# 59            0.006425            0.276106  0.003281    0.510730   1.849756
#
#     leverage  conviction
# 0   0.002126    1.017167
# 1   0.002126    1.338929
# 2   0.001272    1.004674
# 3   0.001272    1.223433
# 4   0.000649    1.002367
# 5   0.000649    1.218835
# 6   0.000954    1.003500
# 7   0.000954    1.157570
# 8   0.001869    1.050239
# 9   0.001869    1.059113
# 10  0.000719    1.019140
# 11  0.000719    1.014047
# 12  0.001344    1.009995
# 13  0.001344    1.160078
# 14  0.000746    1.072232
# 15  0.000746    1.005531
# 16  0.003104    1.203191
# 17  0.003104    1.208846
# 18  0.001628    1.005972
# 19  0.001628    1.506817
# 20  0.001750    1.038960
# 21  0.001750    1.013651
# 22  0.001729    1.080146
# 23  0.001729    1.124064
# 24  0.000001    1.000092
# 25  0.000001    1.000009
# 26  0.002096    1.015963
# 27  0.002096    1.091070
# 28  0.000808    1.005986
# 29  0.000808    1.085519
# 30  0.005518    1.223084
# 31  0.005518    1.047051
# 32  0.009360    1.036395
# 33  0.009360    1.594977
# 34  0.001112    1.038617
# 35  0.001112    1.008454
# 36  0.000709    1.005670
# 37  0.000709    1.076407
# 38  0.014086    1.062079
# 39  0.014086    1.180598
# 40  0.001224    1.126431
# 41  0.001224    1.009838
# 42  0.000118    1.001076
# 43  0.000118    1.000985
# 44  0.001489    1.011902
# 45  0.001489    1.600129
# 46  0.001967    1.007237
# 47  0.001967    1.482025
# 48  0.001302    1.004768
# 49  0.001302    1.380652
# 50  0.000082    1.000299
# 51  0.000082    1.015755
# 52  0.003403    1.012640
# 53  0.003403    1.603539
# 54  0.000271    1.000990
# 55  0.000271    1.041851
# 56  0.001838    1.697928
# 57  0.001838    1.006743
# 58  0.001507    1.005525
# 59  0.001507    1.479537

# %% [markdown]
# Filtramos por el año 2016 con todos los productos. Primer año completo

# %%
df2=df[(df['Fecha_Hora'] > '2016-01-01') & (df['Fecha_Hora'] < '2016-12-31')]
basket2 = (df2.groupby(['Num_Factura', 'Producto'])['Unidades'].sum().unstack().reset_index().fillna(0).set_index('Num_Factura'))
basket_sets2 = basket2.applymap(encode_units)
frequent_itemsets2 = apriori(basket_sets2, min_support=0.002, use_colnames=True)
rules2 = association_rules(frequent_itemsets2, metric="lift", min_threshold=1)
rules2.head(60)
# Out:
# /Users/franciscomanueljimenezpalacios/opt/anaconda3/lib/python3.9/site-packages/mlxtend/frequent_patterns/fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#                                        antecedents  \
# 0                                  (Fruta al peso)
# 1                                     (1/2 huevos)
# 2                                            (Pan)
# 3                                     (1/2 huevos)
# 4                             (Producto de Oferta)
# 5                                     (1/2 huevos)
# 6                                  (Fruta al peso)
# 7                                      (12 huevos)
# 8                                            (Pan)
# 9                                      (12 huevos)
# 10                            (AGUA ERMITICA 1.5L)
# 11                            (Producto de Oferta)
# 12                              (Agua 1,5L BEZOYA)
# 13                            (Producto de Oferta)
# 14                            (Agua 1,5L LANJARON)
# 15                            (Producto de Oferta)
# 16                                           (Pan)
# 17                   (Agua garrafa 8l FONT NATURA)
# 18                             (Bocadillos oferta)
# 19                                (Coca cola 33cl)
# 20                             (Bocadillos oferta)
# 21                            (Producto de Oferta)
# 22                         (Cerveza 33cl VICTORIA)
# 23                             (Cerveza 33cl SKOL)
# 24                                           (Pan)
# 25                (Chorizo tradicion 85gr REVILLA)
# 26                                  (Chuches 0.05)
# 27                            (Producto de Oferta)
# 28                                           (Pan)
# 29                                  (Coca cola 2L)
# 30                            (Producto de Oferta)
# 31                                (Coca cola 33cl)
# 32                                           (Pan)
# 33                          (Coca cola light 33cl)
# 34                            (Producto de Oferta)
# 35                           (Coca cola zero 33cl)
# 36                             (Embutido al corte)
# 37                                 (Fruta al peso)
# 38                                           (Pan)
# 39                             (Embutido al corte)
# 40                             (Embutido al corte)
# 41                            (Producto de Oferta)
# 42                                           (Pan)
# 43                              (Fanta naranja 2L)
# 44                            (Fanta naranja 33cl)
# 45                                           (Pan)
# 46                            (Fanta naranja 33cl)
# 47                            (Producto de Oferta)
# 48                  (Jamon Curado 8u 55gr NAVIDUL)
# 49                                 (Fruta al peso)
# 50                                 (Fruta al peso)
# 51                          (Leche Omega 3 PULEVA)
# 52                                           (Pan)
# 53                                 (Fruta al peso)
# 54                 (Pechuga de pavo 100gr EL POZO)
# 55                                 (Fruta al peso)
# 56                                 (Fruta al peso)
# 57                            (Producto de Oferta)
# 58                                 (Fruta al peso)
# 59  (Queso tierno bajo en sal 80gr GARCIA BAQUERO)
#
#                                        consequents  antecedent support  \
# 0                                     (1/2 huevos)            0.216774
# 1                                  (Fruta al peso)            0.019730
# 2                                     (1/2 huevos)            0.257498
# 3                                            (Pan)            0.019730
# 4                                     (1/2 huevos)            0.116302
# 5                             (Producto de Oferta)            0.019730
# 6                                      (12 huevos)            0.216774
# 7                                  (Fruta al peso)            0.009404
# 8                                      (12 huevos)            0.257498
# 9                                            (Pan)            0.009404
# 10                            (Producto de Oferta)            0.016474
# 11                            (AGUA ERMITICA 1.5L)            0.116302
# 12                            (Producto de Oferta)            0.021187
# 13                              (Agua 1,5L BEZOYA)            0.116302
# 14                            (Producto de Oferta)            0.015253
# 15                            (Agua 1,5L LANJARON)            0.116302
# 16                   (Agua garrafa 8l FONT NATURA)            0.257498
# 17                                           (Pan)            0.008398
# 18                                (Coca cola 33cl)            0.019559
# 19                             (Bocadillos oferta)            0.035904
# 20                            (Producto de Oferta)            0.019559
# 21                             (Bocadillos oferta)            0.116302
# 22                             (Cerveza 33cl SKOL)            0.021251
# 23                         (Cerveza 33cl VICTORIA)            0.019430
# 24                (Chorizo tradicion 85gr REVILLA)            0.257498
# 25                                           (Pan)            0.007262
# 26                            (Producto de Oferta)            0.036075
# 27                                  (Chuches 0.05)            0.116302
# 28                                  (Coca cola 2L)            0.257498
# 29                                           (Pan)            0.026114
# 30                                (Coca cola 33cl)            0.116302
# 31                            (Producto de Oferta)            0.035904
# 32                          (Coca cola light 33cl)            0.257498
# 33                                           (Pan)            0.007669
# 34                           (Coca cola zero 33cl)            0.116302
# 35                            (Producto de Oferta)            0.013046
# 36                                 (Fruta al peso)            0.031362
# 37                             (Embutido al corte)            0.216774
# 38                             (Embutido al corte)            0.257498
# 39                                           (Pan)            0.031362
# 40                            (Producto de Oferta)            0.031362
# 41                             (Embutido al corte)            0.116302
# 42                              (Fanta naranja 2L)            0.257498
# 43                                           (Pan)            0.010840
# 44                                           (Pan)            0.012918
# 45                            (Fanta naranja 33cl)            0.257498
# 46                            (Producto de Oferta)            0.012918
# 47                            (Fanta naranja 33cl)            0.116302
# 48                                 (Fruta al peso)            0.012232
# 49                  (Jamon Curado 8u 55gr NAVIDUL)            0.216774
# 50                          (Leche Omega 3 PULEVA)            0.216774
# 51                                 (Fruta al peso)            0.005463
# 52                                 (Fruta al peso)            0.257498
# 53                                           (Pan)            0.216774
# 54                                 (Fruta al peso)            0.016260
# 55                 (Pechuga de pavo 100gr EL POZO)            0.216774
# 56                            (Producto de Oferta)            0.216774
# 57                                 (Fruta al peso)            0.116302
# 58  (Queso tierno bajo en sal 80gr GARCIA BAQUERO)            0.216774
# 59                                 (Fruta al peso)            0.007819
#
#     consequent support   support  confidence      lift  leverage  conviction
# 0             0.019730  0.007883    0.036367  1.843238  0.003606    1.017265
# 1             0.216774  0.007883    0.399566  1.843238  0.003606    1.304433
# 2             0.019730  0.008548    0.033195  1.682440  0.003467    1.013927
# 3             0.257498  0.008548    0.433225  1.682440  0.003467    1.310047
# 4             0.019730  0.002356    0.020262  1.026938  0.000062    1.000542
# 5             0.116302  0.002356    0.119435  1.026938  0.000062    1.003558
# 6             0.009404  0.004370    0.020160  2.143675  0.002332    1.010977
# 7             0.216774  0.004370    0.464692  2.143675  0.002332    1.463133
# 8             0.009404  0.003385    0.013145  1.397716  0.000963    1.003790
# 9             0.257498  0.003385    0.359909  1.397716  0.000963    1.159994
# 10            0.116302  0.002057    0.124837  1.073386  0.000141    1.009752
# 11            0.016474  0.002057    0.017683  1.073386  0.000141    1.001231
# 12            0.116302  0.002592    0.122346  1.051962  0.000128    1.006886
# 13            0.021187  0.002592    0.022288  1.051962  0.000128    1.001126
# 14            0.116302  0.002185    0.143258  1.231774  0.000411    1.031463
# 15            0.015253  0.002185    0.018788  1.231774  0.000411    1.003603
# 16            0.008398  0.002164    0.008403  1.000603  0.000001    1.000005
# 17            0.257498  0.002164    0.257653  1.000603  0.000001    1.000209
# 18            0.035904  0.003792    0.193866  5.399572  0.003090    1.195951
# 19            0.019559  0.003792    0.105609  5.399572  0.003090    1.096211
# 20            0.116302  0.002506    0.128149  1.101859  0.000232    1.013588
# 21            0.019559  0.002506    0.021551  1.101859  0.000232    1.002036
# 22            0.019430  0.002314    0.108871  5.603194  0.001901    1.100368
# 23            0.021251  0.002314    0.119074  5.603194  0.001901    1.111045
# 24            0.007262  0.003299    0.012812  1.764198  0.001429    1.005622
# 25            0.257498  0.003299    0.454277  1.764198  0.001429    1.360585
# 26            0.116302  0.005998    0.166271  1.429641  0.001803    1.059933
# 27            0.036075  0.005998    0.051575  1.429641  0.001803    1.016342
# 28            0.026114  0.007412    0.028785  1.102297  0.000688    1.002751
# 29            0.257498  0.007412    0.283839  1.102297  0.000688    1.036781
# 30            0.035904  0.005570    0.047891  1.333860  0.001394    1.012590
# 31            0.116302  0.005570    0.155131  1.333860  0.001394    1.045958
# 32            0.007669  0.002185    0.008486  1.106480  0.000210    1.000824
# 33            0.257498  0.002185    0.284916  1.106480  0.000210    1.038343
# 34            0.013046  0.002249    0.019341  1.482460  0.000732    1.006418
# 35            0.116302  0.002249    0.172414  1.482460  0.000732    1.067801
# 36            0.216774  0.009833    0.313525  1.446322  0.003034    1.140938
# 37            0.031362  0.009833    0.045360  1.446322  0.003034    1.014663
# 38            0.031362  0.013860    0.053827  1.716286  0.005785    1.023742
# 39            0.257498  0.013860    0.441940  1.716286  0.005785    1.330506
# 40            0.116302  0.004092    0.130464  1.121769  0.000444    1.016287
# 41            0.031362  0.004092    0.035181  1.121769  0.000444    1.003958
# 42            0.010840  0.002935    0.011398  1.051469  0.000144    1.000564
# 43            0.257498  0.002935    0.270751  1.051469  0.000144    1.018174
# 44            0.257498  0.004113    0.318408  1.236546  0.000787    1.089364
# 45            0.012918  0.004113    0.015973  1.236546  0.000787    1.003105
# 46            0.116302  0.002356    0.182421  1.568507  0.000854    1.080871
# 47            0.012918  0.002356    0.020262  1.568507  0.000854    1.007496
# 48            0.216774  0.003942    0.322242  1.486534  0.001290    1.155613
# 49            0.012232  0.003942    0.018184  1.486534  0.001290    1.006062
# 50            0.005463  0.002142    0.009882  1.809060  0.000958    1.004464
# 51            0.216774  0.002142    0.392157  1.809060  0.000958    1.288533
# 52            0.216774  0.081962    0.318303  1.468364  0.026144    1.148936
# 53            0.257498  0.081962    0.378101  1.468364  0.026144    1.193926
# 54            0.216774  0.003963    0.243742  1.124406  0.000438    1.035660
# 55            0.016260  0.003963    0.018282  1.124406  0.000438    1.002060
# 56            0.116302  0.032305    0.149027  1.281371  0.007094    1.038455
# 57            0.216774  0.032305    0.277768  1.281371  0.007094    1.084452
# 58            0.007819  0.002378    0.010969  1.402889  0.000683    1.003185
# 59            0.216774  0.002378    0.304110  1.402889  0.000683    1.125502

# %% [markdown]
# Filtramos por el año 2020 con todos los productos. Año de la pandemia

# %%
df3=df[(df['Fecha_Hora'] > '2020-01-01') & (df['Fecha_Hora'] < '2020-12-31')]
basket3 = (df3.groupby(['Num_Factura', 'Producto'])['Unidades'].sum().unstack().reset_index().fillna(0).set_index('Num_Factura'))
basket_sets3 = basket3.applymap(encode_units)
frequent_itemsets3 = apriori(basket_sets3, min_support=0.002, use_colnames=True)
rules3 = association_rules(frequent_itemsets3, metric="lift", min_threshold=1)
rules3.head(60)
# Out:
# /Users/franciscomanueljimenezpalacios/opt/anaconda3/lib/python3.9/site-packages/mlxtend/frequent_patterns/fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#                            antecedents                         consequents  \
# 0                      (Fruta al peso)                        (1/2 huevos)
# 1                         (1/2 huevos)                     (Fruta al peso)
# 2                                (Pan)                        (1/2 huevos)
# 3                         (1/2 huevos)                               (Pan)
# 4                      (Fruta al peso)                         (12 huevos)
# 5                          (12 huevos)                     (Fruta al peso)
# 6                                (Pan)                         (12 huevos)
# 7                          (12 huevos)                               (Pan)
# 8                      (Fruta al peso)       (Agua garrafa 5l FONT NATURA)
# 9        (Agua garrafa 5l FONT NATURA)                     (Fruta al peso)
# 10                               (Pan)       (Agua garrafa 5l FONT NATURA)
# 11       (Agua garrafa 5l FONT NATURA)                               (Pan)
# 12                     (Fruta al peso)       (Agua garrafa 8l FONT NATURA)
# 13       (Agua garrafa 8l FONT NATURA)                     (Fruta al peso)
# 14                               (Pan)       (Agua garrafa 8l FONT NATURA)
# 15       (Agua garrafa 8l FONT NATURA)                               (Pan)
# 16  (Blue Chameleon Bebida Energetica)                      (Chuches 0.05)
# 17                      (Chuches 0.05)  (Blue Chameleon Bebida Energetica)
# 18                 (Bocadillos oferta)                    (Coca cola 33cl)
# 19                    (Coca cola 33cl)                 (Bocadillos oferta)
# 20                (Producto de Oferta)                 (Bocadillos oferta)
# 21                 (Bocadillos oferta)                (Producto de Oferta)
# 22                               (Pan)                           (Caña Qe)
# 23                           (Caña Qe)                               (Pan)
# 24                           (Caña Qe)                (Producto de Oferta)
# 25                (Producto de Oferta)                           (Caña Qe)
# 26                 (Cerveza 33cl SKOL)                   (Cerveza 1l SKOL)
# 27                   (Cerveza 1l SKOL)                 (Cerveza 33cl SKOL)
# 28                               (Pan)    (Chorizo tradicion 85gr REVILLA)
# 29    (Chorizo tradicion 85gr REVILLA)                               (Pan)
# 30     (Salchichon extra 85gr REVILLA)    (Chorizo tradicion 85gr REVILLA)
# 31    (Chorizo tradicion 85gr REVILLA)     (Salchichon extra 85gr REVILLA)
# 32                      (Chuches 0.05)               (Gusanitos 0,35 RISI)
# 33               (Gusanitos 0,35 RISI)                      (Chuches 0.05)
# 34                      (Chuches 0.05)                (Producto de Oferta)
# 35                (Producto de Oferta)                      (Chuches 0.05)
# 36                      (Coca cola 2L)                (Producto de Oferta)
# 37                (Producto de Oferta)                      (Coca cola 2L)
# 38                (Producto de Oferta)                    (Coca cola 33cl)
# 39                    (Coca cola 33cl)                (Producto de Oferta)
# 40                (Producto de Oferta)               (Coca cola zero 33cl)
# 41               (Coca cola zero 33cl)                (Producto de Oferta)
# 42                               (Pan)            (Cola Cola Zero Cafeina)
# 43            (Cola Cola Zero Cafeina)                               (Pan)
# 44                               (Pan)       (Donuts Blanco Oferta Pack 4)
# 45       (Donuts Blanco Oferta Pack 4)                               (Pan)
# 46                 (Embutido al corte)                     (Fruta al peso)
# 47                     (Fruta al peso)                 (Embutido al corte)
# 48                               (Pan)                 (Embutido al corte)
# 49                 (Embutido al corte)                               (Pan)
# 50                 (Embutido al corte)                (Producto de Oferta)
# 51                (Producto de Oferta)                 (Embutido al corte)
# 52                     (Fruta al peso)               (Gusanitos 0,35 RISI)
# 53               (Gusanitos 0,35 RISI)                     (Fruta al peso)
# 54      (Jamon Curado 8u 55gr NAVIDUL)                     (Fruta al peso)
# 55                     (Fruta al peso)      (Jamon Curado 8u 55gr NAVIDUL)
# 56                     (Fruta al peso)        (PACK AGUA 1.5L FONT NATURA)
# 57        (PACK AGUA 1.5L FONT NATURA)                     (Fruta al peso)
# 58                               (Pan)                     (Fruta al peso)
# 59                     (Fruta al peso)                               (Pan)
#
#     antecedent support  consequent support   support  confidence       lift  \
# 0             0.173556            0.016816  0.006953    0.040061   2.382298
# 1             0.016816            0.173556  0.006953    0.413462   2.382298
# 2             0.301294            0.016816  0.007702    0.025565   1.520251
# 3             0.016816            0.301294  0.007702    0.458042   1.520251
# 4             0.173556            0.011274  0.004086    0.023545   2.088384
# 5             0.011274            0.173556  0.004086    0.362451   2.088384
# 6             0.301294            0.011274  0.004366    0.014490   1.285202
# 7             0.011274            0.301294  0.004366    0.387223   1.285202
# 8             0.173556            0.010128  0.002602    0.014991   1.480181
# 9             0.010128            0.173556  0.002602    0.256894   1.480181
# 10            0.301294            0.010128  0.003410    0.011319   1.117581
# 11            0.010128            0.301294  0.003410    0.336720   1.117581
# 12            0.173556            0.010686  0.002558    0.014737   1.379036
# 13            0.010686            0.173556  0.002558    0.239340   1.379036
# 14            0.301294            0.010686  0.003881    0.012880   1.205257
# 15            0.010686            0.301294  0.003881    0.363136   1.205257
# 16            0.029840            0.048758  0.002352    0.078818   1.616512
# 17            0.048758            0.029840  0.002352    0.048236   1.616512
# 18            0.017698            0.022946  0.002969    0.167774   7.311769
# 19            0.022946            0.017698  0.002969    0.129404   7.311769
# 20            0.120814            0.017698  0.003440    0.028471   1.608684
# 21            0.017698            0.120814  0.003440    0.194352   1.608684
# 22            0.301294            0.011407  0.003881    0.012880   1.129152
# 23            0.011407            0.301294  0.003881    0.340206   1.129152
# 24            0.011407            0.120814  0.002043    0.179124   1.482636
# 25            0.120814            0.011407  0.002043    0.016912   1.482636
# 26            0.027223            0.019315  0.002881    0.105832   5.479238
# 27            0.019315            0.027223  0.002881    0.149163   5.479238
# 28            0.301294            0.007041  0.003925    0.013026   1.850060
# 29            0.007041            0.301294  0.003925    0.557411   1.850060
# 30            0.007276            0.007041  0.002220    0.305051  43.324814
# 31            0.007041            0.007276  0.002220    0.315240  43.324814
# 32            0.048758            0.014082  0.002234    0.045825   3.254116
# 33            0.014082            0.048758  0.002234    0.158664   3.254116
# 34            0.048758            0.120814  0.009775    0.200482   1.659425
# 35            0.120814            0.048758  0.009775    0.080910   1.659425
# 36            0.020403            0.120814  0.002984    0.146254   1.210565
# 37            0.120814            0.020403  0.002984    0.024699   1.210565
# 38            0.120814            0.022946  0.004645    0.038447   1.675582
# 39            0.022946            0.120814  0.004645    0.202434   1.675582
# 40            0.120814            0.012245  0.002631    0.021779   1.778646
# 41            0.012245            0.120814  0.002631    0.214886   1.778646
# 42            0.301294            0.007467  0.002558    0.008489   1.136830
# 43            0.007467            0.301294  0.002558    0.342520   1.136830
# 44            0.301294            0.008878  0.003263    0.010831   1.219906
# 45            0.008878            0.301294  0.003263    0.367550   1.219906
# 46            0.040556            0.173556  0.015170    0.374049   2.155207
# 47            0.173556            0.040556  0.015170    0.087406   2.155207
# 48            0.301294            0.040556  0.022872    0.075914   1.871837
# 49            0.040556            0.301294  0.022872    0.563972   1.871837
# 50            0.040556            0.120814  0.006659    0.164190   1.359027
# 51            0.120814            0.040556  0.006659    0.055116   1.359027
# 52            0.173556            0.014082  0.002572    0.014822   1.052527
# 53            0.014082            0.173556  0.002572    0.182672   1.052527
# 54            0.009055            0.173556  0.003013    0.332792   1.917494
# 55            0.173556            0.009055  0.003013    0.017363   1.917494
# 56            0.173556            0.012494  0.003102    0.017871   1.430291
# 57            0.012494            0.173556  0.003102    0.248235   1.430291
# 58            0.301294            0.173556  0.069749    0.231497   1.333849
# 59            0.173556            0.301294  0.069749    0.401880   1.333849
#
#     leverage  conviction
# 0   0.004034    1.024215
# 1   0.004034    1.409020
# 2   0.002636    1.008978
# 3   0.002636    1.289226
# 4   0.002130    1.012567
# 5   0.002130    1.296284
# 6   0.000969    1.003263
# 7   0.000969    1.140229
# 8   0.000844    1.004937
# 9   0.000844    1.112149
# 10  0.000359    1.001204
# 11  0.000359    1.053411
# 12  0.000703    1.004111
# 13  0.000703    1.086483
# 14  0.000661    1.002222
# 15  0.000661    1.097105
# 16  0.000897    1.032632
# 17  0.000897    1.019329
# 18  0.002563    1.174025
# 19  0.002563    1.128310
# 20  0.001301    1.011088
# 21  0.001301    1.091278
# 22  0.000444    1.001492
# 23  0.000444    1.058977
# 24  0.000665    1.071033
# 25  0.000665    1.005600
# 26  0.002355    1.096756
# 27  0.002355    1.143317
# 28  0.001803    1.006064
# 29  0.001803    1.578681
# 30  0.002168    1.428822
# 31  0.002168    1.449740
# 32  0.001548    1.033267
# 33  0.001548    1.130633
# 34  0.003884    1.099645
# 35  0.003884    1.034983
# 36  0.000519    1.029797
# 37  0.000519    1.004405
# 38  0.001873    1.016122
# 39  0.001873    1.102336
# 40  0.001152    1.009746
# 41  0.001152    1.119819
# 42  0.000308    1.001031
# 43  0.000308    1.062703
# 44  0.000588    1.001974
# 45  0.000588    1.104761
# 46  0.008131    1.320301
# 47  0.008131    1.051337
# 48  0.010653    1.038263
# 49  0.010653    1.602436
# 50  0.001759    1.051896
# 51  0.001759    1.015410
# 52  0.000128    1.000751
# 53  0.000128    1.011154
# 54  0.001442    1.238661
# 55  0.001442    1.008455
# 56  0.000933    1.005474
# 57  0.000933    1.099339
# 58  0.017457    1.075395
# 59  0.017457    1.168171
